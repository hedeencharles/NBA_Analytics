# %%
pip install basketball-reference-scraper
# Out:
# ...
#   Using cached requests-2.22.0-py2.py3-none-any.whl (57 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Error checking for conflicts.
# Traceback (most recent call last):
#   File "C:\Users\15309\anaconda3\envs\Python_Data\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "C:\Users\15309\anaconda3\envs\Python_Data\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\15309\anaconda3\envs\Python_Data\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
# ...

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc

# %%
from basketball_reference_scraper.players import get_stats, get_game_logs, get_player_headshot

# %%
lebron_james = get_stats(name='LeBron James', stat_type='Advanced', playoffs=False, career=False)
anthony_davis = get_stats(name='Anthony Davis', stat_type='Advanced', playoffs=False, career=False)
james_harden = get_stats(name='James Harden', stat_type='Advanced', playoffs=False, career=False)

# %%
from basketball_reference_scraper.seasons import get_schedule, get_standings

# %%
get_schedule(season='2020', playoffs=False)
# Out:
#          DATE               VISITOR VISITOR_PTS                   HOME  \
# 0  2019-10-22  New Orleans Pelicans         122        Toronto Raptors
# 1  2019-10-22    Los Angeles Lakers         102   Los Angeles Clippers
# 2  2019-10-23         Chicago Bulls         125      Charlotte Hornets
# 3  2019-10-23       Detroit Pistons         119         Indiana Pacers
# 4  2019-10-23   Cleveland Cavaliers          85          Orlando Magic
# ..        ...                   ...         ...                    ...
# 63 2019-10-30  Los Angeles Clippers          96              Utah Jazz
# 64 2019-10-30          Phoenix Suns         121  Golden State Warriors
# 65 2019-10-31            Miami Heat         106          Atlanta Hawks
# 66 2019-10-31        Denver Nuggets         107   New Orleans Pelicans
# 67 2019-10-31     San Antonio Spurs          97   Los Angeles Clippers
#
#    HOME_PTS
# 0       130
# 1       112
# 2       126
# 3       110
# 4        94
# ..      ...
# 63      110
# ...
